# %%
import pandas as pd
ebola = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/country_timeseries.csv')
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# 1              NaN            NaN                 NaN          NaN
# 2              NaN            NaN                 NaN          NaN
# 3              NaN            NaN                 NaN          NaN
# 4              NaN            NaN                 NaN          NaN
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 0           NaN         1786.0             NaN              2977.0
# 1           NaN         1781.0             NaN              2943.0
# 2           NaN         1767.0          3496.0              2915.0
# 3           NaN            NaN          3496.0                 NaN
# 4           NaN         1739.0          3471.0              2827.0
# ..          ...            ...             ...                 ...
# 117         NaN           66.0             6.0                 5.0
# 118         NaN           62.0             NaN                 NaN
# 119         NaN           60.0             NaN                 NaN
# 120         NaN           59.0             NaN                 NaN
# 121         NaN           29.0             NaN                 NaN
#
#      Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 0               NaN             NaN                  NaN           NaN
# 1               NaN             NaN                  NaN           NaN
# 2               NaN             NaN                  NaN           NaN
# 3               NaN             NaN                  NaN           NaN
# 4               NaN             NaN                  NaN           NaN
# ..              ...             ...                  ...           ...
# 117             NaN             NaN                  NaN           NaN
# 118             NaN             NaN                  NaN           NaN
# 119             NaN             NaN                  NaN           NaN
# 120             NaN             NaN                  NaN           NaN
# 121             NaN             NaN                  NaN           NaN
#
#      Deaths_Mali
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 117          NaN
# 118          NaN
# 119          NaN
# 120          NaN
# 121          NaN
#
# [122 rows x 18 columns]

# %%
ebola['Cases_Guinea'].sum()
ebola.Cases_Guinea.sum()
ebola.Cases_Guinea.sum(skipna=True)
# Out:
# nan

# %%
# 시계열 : 시간에 따른 데이터 분석
from datetime import datetime

now1 = datetime.now()
print(now1)

now2 = datetime.today()
print(now2)
# Out:
# 2023-12-29 09:23:04.353790
# 2023-12-29 09:23:04.353791

# %%
t1 = datetime.now()
t2 = datetime(1970,1,1)
t3 = datetime(1970,12,10,12,30,56)
print(t1)
print(t2)
print(t3)

diff1 = t1 - t2        # day 로 출력 : 현재 날짜 - 과거 날짜
print(diff1)

print(type(t1))
print(type(t2))
print(type(diff1))     # datetime의 연산 이후에는 timedelta 형이 된다.

diff2 = t2 - t1
print(diff2)           # 음수 출력
print(type(diff2))
# Out:
# 2023-12-29 09:27:25.409794
# 1970-01-01 00:00:00
# 1970-12-10 12:30:56
# 19720 days, 9:27:25.409794
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.timedelta'>
# -19721 days, 14:32:34.590206
# <class 'datetime.timedelta'>

# %%
ebola.info()
ebola['date_dt'] = pd.to_datetime(ebola['Date'],format='%m/%d/%Y') # %Y : yyyy / %y : yy (소문 대문 서로 사용법이 다름.)
ebola
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
#  18  date_dt              122 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(16), int64(1), object(1)
# memory usage: 18.2+ KB
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# 1              NaN            NaN                 NaN          NaN
# 2              NaN            NaN                 NaN          NaN
# 3              NaN            NaN                 NaN          NaN
# 4              NaN            NaN                 NaN          NaN
# ..             ...            ...                 ...          ...
# 117            NaN            NaN                 NaN          NaN
# 118            NaN            NaN                 NaN          NaN
# 119            NaN            NaN                 NaN          NaN
# 120            NaN            NaN                 NaN          NaN
# 121            NaN            NaN                 NaN          NaN
#
#      Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 0           NaN         1786.0             NaN              2977.0
# 1           NaN         1781.0             NaN              2943.0
# 2           NaN         1767.0          3496.0              2915.0
# 3           NaN            NaN          3496.0                 NaN
# 4           NaN         1739.0          3471.0              2827.0
# ..          ...            ...             ...                 ...
# 117         NaN           66.0             6.0                 5.0
# 118         NaN           62.0             NaN                 NaN
# 119         NaN           60.0             NaN                 NaN
# 120         NaN           59.0             NaN                 NaN
# 121         NaN           29.0             NaN                 NaN
#
#      Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 0               NaN             NaN                  NaN           NaN
# 1               NaN             NaN                  NaN           NaN
# 2               NaN             NaN                  NaN           NaN
# 3               NaN             NaN                  NaN           NaN
# 4               NaN             NaN                  NaN           NaN
# ..              ...             ...                  ...           ...
# 117             NaN             NaN                  NaN           NaN
# 118             NaN             NaN                  NaN           NaN
# 119             NaN             NaN                  NaN           NaN
# 120             NaN             NaN                  NaN           NaN
# 121             NaN             NaN                  NaN           NaN
#
#      Deaths_Mali    date_dt
# 0            NaN 2015-01-05
# 1            NaN 2015-01-04
# 2            NaN 2015-01-03
# 3            NaN 2015-01-02
# 4            NaN 2014-12-31
# ..           ...        ...
# 117          NaN 2014-03-27
# 118          NaN 2014-03-26
# 119          NaN 2014-03-25
# 120          NaN 2014-03-24
# 121          NaN 2014-03-22
#
# [122 rows x 19 columns]

# %%
test_df1 = pd.DataFrame({'order_day':['01/01/15','02/01/15','03/01/15']})
test_df1['date_dt1'] = pd.to_datetime(test_df1['order_day'],format = '%m/%d/%y')
test_df1['date_dt2'] = pd.to_datetime(test_df1['order_day'],format = '%d/%m/%y')
test_df1['date_dt3'] = pd.to_datetime(test_df1['order_day'],format = '%y/%m/%d')
test_df1
# Out:
#   order_day   date_dt1   date_dt2   date_dt3
# 0  01/01/15 2015-01-01 2015-01-01 2001-01-15
# 1  02/01/15 2015-02-01 2015-01-02 2002-01-15
# 2  03/01/15 2015-03-01 2015-01-03 2003-01-15

# %%
now = datetime.now()
now

nowDate = now.strftime('%Y-%m-%d') # String First Time
nowDate

nowDate = now.strftime('%H:%M:%S')
nowDate

nowDatetime = now.strftime('%Y-%m-%d %H:%M:%S')
nowDatetime
# Out:
# '2023-12-29 10:05:05'

# %%
date_series = pd.Series(['2018-05-16','2018-05-17','2018-05-18'])
# date_series.info()
d1 = pd.to_datetime(date_series)
# d1.info()
d1[0] # .year , .month , .day 등으로 원하는 값 받기
d1[0].year
d1[0].month
d1[0].day
# Out:
# 16

# %%
ebola
ebola.columns   # 열

ebola[['Date','date_dt']].head()
ebola['date_dt'][0].year
ebola['date_dt'][0].month
ebola['date_dt'][0].day

ebola['date_dt'].dt.year     # .dt를 주면 해당 컬럼의 모든 정보를 가져올 수 있음.
ebola['date_dt'].dt.month
ebola['date_dt'].dt.day
# Out:
# 0       5
# 1       4
# 2       3
# 3       2
# 4      31
#        ..
# 117    27
# 118    26
# 119    25
# 120    24
# 121    22
# Name: date_dt, Length: 122, dtype: int32

# %%
ebola['year'] = ebola['date_dt'].dt.year
ebola[['Date','date_dt','year']].head()

ebola['month'] , ebola['day'] = ebola['date_dt'].dt.month , ebola['date_dt'].dt.day
ebola[['Date','date_dt','year','month','day']].head()
# Out:
#          Date    date_dt  year  month  day
# 0    1/5/2015 2015-01-05  2015      1    5
# 1    1/4/2015 2015-01-04  2015      1    4
# 2    1/3/2015 2015-01-03  2015      1    3
# 3    1/2/2015 2015-01-02  2015      1    2
# 4  12/31/2014 2014-12-31  2014     12   31

# %%
# 에볼라 최초 발병일 계산하기
ebola[ebola['date_dt'] == ebola['date_dt'].min()]   # Timestamp : 1970-01-01 00:00:00.00000 이 최소 값이다.

# 에볼라 유행 기간
ebola['outbreak_d'] = ebola['date_dt'] - ebola['date_dt'].min()
ebola[['Date','Day','outbreak_d']].head()
# Out:
#          Date  Day outbreak_d
# 0    1/5/2015  289   289 days
# 1    1/4/2015  288   288 days
# 2    1/3/2015  287   287 days
# 3    1/2/2015  286   286 days
# 4  12/31/2014  284   284 days

# %%
banks = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/banklist.csv')
banks.head()

banks_no_dates = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/banklist.csv', parse_dates=[5,6])
banks_no_dates.head()

banks = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/banklist.csv' , parse_dates=[5,6])
# Out:
# C:\Users\sdedu\AppData\Local\Temp\ipykernel_6752\2908890056.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks_no_dates = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/banklist.csv', parse_dates=[5,6])
# C:\Users\sdedu\AppData\Local\Temp\ipykernel_6752\2908890056.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks_no_dates = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/banklist.csv', parse_dates=[5,6])
# C:\Users\sdedu\AppData\Local\Temp\ipykernel_6752\2908890056.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/banklist.csv' , parse_dates=[5,6])
# C:\Users\sdedu\AppData\Local\Temp\ipykernel_6752\2908890056.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/banklist.csv' , parse_dates=[5,6])

# %%
banks.columns
banks['closing_quarter'] , banks['closing_year'] = banks['Closing Date'].dt.quarter , banks['Closing Date'].dt.year
banks[['Closing Date','closing_quarter','closing_year']]
# Out:
#     Closing Date  closing_quarter  closing_year
# 0     2017-12-15                4          2017
# 1     2017-10-13                4          2017
# 2     2017-05-26                2          2017
# 3     2017-05-05                2          2017
# 4     2017-04-28                2          2017
# ..           ...              ...           ...
# 550   2001-07-27                3          2001
# 551   2001-05-03                2          2001
# 552   2001-02-02                1          2001
# 553   2000-12-14                4          2000
# 554   2000-10-13                4          2000
#
# [555 rows x 3 columns]

# %%
# 각 년도별 파산 은행 갯수
banks.groupby('closing_year').size()

# 각 년도별 분기에 따라 파산 은행 갯수는?
banks.groupby(['closing_year','closing_quarter']).size()
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
#               2                  45
#               3                  41
#               4                  30
# 2011          1                  26
#               2                  22
#               3                  26
#               4                  18
# 2012          1                  16
#               2                  15
#               3                  12
#               4                   8
# 2013          1                   4
#               2                  12
#               3                   6
#               4                   2
# 2014          1                   5
#               2                   7
#               3                   2
#               4                   4
# 2015          1                   4
#               2                   1
#               3                   1
#               4                   2
# 2016          1                   1
#               2                   2
#               3                   2
# 2017          1                   3
#               2                   3
#               4                   2
# dtype: int64

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots()
ax = banks.groupby('closing_year').size().plot()
plt.show()

ax = banks.groupby(['closing_year','closing_quarter']).size().plot()
plt.show()

# %%
# 테슬라 주식 데이터로 시간 계산하기

# !pip install pandas_datareader
# http://www.quandl.com
# import pandas_datareader as pdr
# pd.core.common.is_list_like = pd.api.types.is_list_like
# tesla = pdr.get_data_quandl('TSLA',api_key="")

tesla = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/tesla_stock_quandl.csv',parse_dates=[0])
tesla
# Out:
#            Date    Open      High     Low   Close      Volume  ExDividend  \
# 0    2018-03-27  304.00  304.2700  277.18  279.18  13696168.0         0.0
# 1    2018-03-26  307.34  307.5900  291.36  304.18   8324639.0         0.0
# 2    2018-03-23  311.25  311.6100  300.45  301.54   6600538.0         0.0
# 3    2018-03-22  313.89  318.8200  308.18  309.10   4914307.0         0.0
# 4    2018-03-21  310.25  322.4400  310.19  316.53   5927881.0         0.0
# ...         ...     ...       ...     ...     ...         ...         ...
# 1944 2010-07-06   20.00   20.0000   15.83   16.11   6866900.0         0.0
# 1945 2010-07-02   23.00   23.1000   18.71   19.20   5139800.0         0.0
# 1946 2010-07-01   25.00   25.9200   20.27   21.96   8218800.0         0.0
# 1947 2010-06-30   25.79   30.4192   23.30   23.83  17187100.0         0.0
# 1948 2010-06-29   19.00   25.0000   17.54   23.89  18766300.0         0.0
#
#       SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose   AdjVolume
# 0            1.0   304.00  304.2700  277.18    279.18  13696168.0
# 1            1.0   307.34  307.5900  291.36    304.18   8324639.0
# 2            1.0   311.25  311.6100  300.45    301.54   6600538.0
# 3            1.0   313.89  318.8200  308.18    309.10   4914307.0
# 4            1.0   310.25  322.4400  310.19    316.53   5927881.0
# ...          ...      ...       ...     ...       ...         ...
# 1944         1.0    20.00   20.0000   15.83     16.11   6866900.0
# 1945         1.0    23.00   23.1000   18.71     19.20   5139800.0
# 1946         1.0    25.00   25.9200   20.27     21.96   8218800.0
# 1947         1.0    25.79   30.4192   23.30     23.83  17187100.0
# 1948         1.0    19.00   25.0000   17.54     23.89  18766300.0
#
# [1949 rows x 13 columns]

# %%
# 2010년도 6월의 주식 출력!     팬시 인덱스 사용하여 출력하기
tesla[(tesla['Date'].dt.year == 2010) & (tesla['Date'].dt.month == 6)]
# Out:
#            Date   Open     High    Low  Close      Volume  ExDividend  \
# 1947 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0         0.0
# 1948 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0         0.0
#
#       SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 1947         1.0    25.79  30.4192   23.30     23.83  17187100.0
# 1948         1.0    19.00  25.0000   17.54     23.89  18766300.0

# %%
# 
tesla.shape
tesla.columns
tesla.index
tesla['Date']

# 인덱스 바꾸기
tesla.index = tesla['Date']
tesla
# Out:
#                  Date    Open      High     Low   Close      Volume  \
# Date
# 2018-03-27 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0
# 2018-03-26 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0
# 2018-03-23 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0
# 2018-03-22 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0
# 2018-03-21 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0
# ...               ...     ...       ...     ...     ...         ...
# 2010-07-06 2010-07-06   20.00   20.0000   15.83   16.11   6866900.0
# 2010-07-02 2010-07-02   23.00   23.1000   18.71   19.20   5139800.0
# 2010-07-01 2010-07-01   25.00   25.9200   20.27   21.96   8218800.0
# 2010-06-30 2010-06-30   25.79   30.4192   23.30   23.83  17187100.0
# 2010-06-29 2010-06-29   19.00   25.0000   17.54   23.89  18766300.0
#
#             ExDividend  SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose  \
# Date
# 2018-03-27         0.0         1.0   304.00  304.2700  277.18    279.18
# 2018-03-26         0.0         1.0   307.34  307.5900  291.36    304.18
# 2018-03-23         0.0         1.0   311.25  311.6100  300.45    301.54
# 2018-03-22         0.0         1.0   313.89  318.8200  308.18    309.10
# 2018-03-21         0.0         1.0   310.25  322.4400  310.19    316.53
# ...                ...         ...      ...       ...     ...       ...
# 2010-07-06         0.0         1.0    20.00   20.0000   15.83     16.11
# 2010-07-02         0.0         1.0    23.00   23.1000   18.71     19.20
# 2010-07-01         0.0         1.0    25.00   25.9200   20.27     21.96
# 2010-06-30         0.0         1.0    25.79   30.4192   23.30     23.83
# 2010-06-29         0.0         1.0    19.00   25.0000   17.54     23.89
#
#              AdjVolume
# Date
# 2018-03-27  13696168.0
# 2018-03-26   8324639.0
# 2018-03-23   6600538.0
# 2018-03-22   4914307.0
# 2018-03-21   5927881.0
# ...                ...
# 2010-07-06   6866900.0
# 2010-07-02   5139800.0
# 2010-07-01   8218800.0
# 2010-06-30  17187100.0
# 2010-06-29  18766300.0
#
# [1949 rows x 13 columns]

# %%
tesla.iloc[:5,:5]
# Out:
#                  Date    Open    High     Low   Close
# Date
# 2018-03-27 2018-03-27  304.00  304.27  277.18  279.18
# 2018-03-26 2018-03-26  307.34  307.59  291.36  304.18
# 2018-03-23 2018-03-23  311.25  311.61  300.45  301.54
# 2018-03-22 2018-03-22  313.89  318.82  308.18  309.10
# 2018-03-21 2018-03-21  310.25  322.44  310.19  316.53

# %%
tesla.loc['2018'].iloc[:5,:5]
# Out:
#                  Date    Open    High     Low   Close
# Date
# 2018-03-27 2018-03-27  304.00  304.27  277.18  279.18
# 2018-03-26 2018-03-26  307.34  307.59  291.36  304.18
# 2018-03-23 2018-03-23  311.25  311.61  300.45  301.54
# 2018-03-22 2018-03-22  313.89  318.82  308.18  309.10
# 2018-03-21 2018-03-21  310.25  322.44  310.19  316.53

# %%
#### 2018년도 3월 데이터를 5개 행과 5개 열로 출력
tesla[(tesla['Date'].dt.year == 2018) & (tesla['Date'].dt.month == 3)].iloc[:5,:5]   # 두 개는 같은 결과값을 도출함.
tesla.loc['2018-03'].iloc[:5,:5]
# Out:
#                  Date    Open    High     Low   Close
# Date
# 2018-03-27 2018-03-27  304.00  304.27  277.18  279.18
# 2018-03-26 2018-03-26  307.34  307.59  291.36  304.18
# 2018-03-23 2018-03-23  311.25  311.61  300.45  301.54
# 2018-03-22 2018-03-22  313.89  318.82  308.18  309.10
# 2018-03-21 2018-03-21  310.25  322.44  310.19  316.53

# %%
tesla
# Out:
#                  Date    Open      High     Low   Close      Volume  \
# Date
# 2018-03-27 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0
# 2018-03-26 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0
# 2018-03-23 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0
# 2018-03-22 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0
# 2018-03-21 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0
# ...               ...     ...       ...     ...     ...         ...
# 2010-07-06 2010-07-06   20.00   20.0000   15.83   16.11   6866900.0
# 2010-07-02 2010-07-02   23.00   23.1000   18.71   19.20   5139800.0
# 2010-07-01 2010-07-01   25.00   25.9200   20.27   21.96   8218800.0
# 2010-06-30 2010-06-30   25.79   30.4192   23.30   23.83  17187100.0
# 2010-06-29 2010-06-29   19.00   25.0000   17.54   23.89  18766300.0
#
#             ExDividend  SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose  \
# Date
# 2018-03-27         0.0         1.0   304.00  304.2700  277.18    279.18
# 2018-03-26         0.0         1.0   307.34  307.5900  291.36    304.18
# 2018-03-23         0.0         1.0   311.25  311.6100  300.45    301.54
# 2018-03-22         0.0         1.0   313.89  318.8200  308.18    309.10
# 2018-03-21         0.0         1.0   310.25  322.4400  310.19    316.53
# ...                ...         ...      ...       ...     ...       ...
# 2010-07-06         0.0         1.0    20.00   20.0000   15.83     16.11
# 2010-07-02         0.0         1.0    23.00   23.1000   18.71     19.20
# 2010-07-01         0.0         1.0    25.00   25.9200   20.27     21.96
# 2010-06-30         0.0         1.0    25.79   30.4192   23.30     23.83
# 2010-06-29         0.0         1.0    19.00   25.0000   17.54     23.89
#
#              AdjVolume
# Date
# 2018-03-27  13696168.0
# 2018-03-26   8324639.0
# 2018-03-23   6600538.0
# 2018-03-22   4914307.0
# 2018-03-21   5927881.0
# ...                ...
# 2010-07-06   6866900.0
# 2010-07-02   5139800.0
# 2010-07-01   8218800.0
# 2010-06-30  17187100.0
# 2010-06-29  18766300.0
#
# [1949 rows x 13 columns]

# %%
# 시간 간격을 인덱스로 설정하여 데이터 추출하기
tesla.columns
tesla.index = tesla['Date'] - tesla['Date'].min()
tesla
# Out:
#                 Date    Open      High     Low   Close      Volume  \
# Date
# 2828 days 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0
# 2827 days 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0
# 2824 days 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0
# 2823 days 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0
# 2822 days 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0
# ...              ...     ...       ...     ...     ...         ...
# 7 days    2010-07-06   20.00   20.0000   15.83   16.11   6866900.0
# 3 days    2010-07-02   23.00   23.1000   18.71   19.20   5139800.0
# 2 days    2010-07-01   25.00   25.9200   20.27   21.96   8218800.0
# 1 days    2010-06-30   25.79   30.4192   23.30   23.83  17187100.0
# 0 days    2010-06-29   19.00   25.0000   17.54   23.89  18766300.0
#
#            ExDividend  SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose  \
# Date
# 2828 days         0.0         1.0   304.00  304.2700  277.18    279.18
# 2827 days         0.0         1.0   307.34  307.5900  291.36    304.18
# 2824 days         0.0         1.0   311.25  311.6100  300.45    301.54
# 2823 days         0.0         1.0   313.89  318.8200  308.18    309.10
# 2822 days         0.0         1.0   310.25  322.4400  310.19    316.53
# ...               ...         ...      ...       ...     ...       ...
# 7 days            0.0         1.0    20.00   20.0000   15.83     16.11
# 3 days            0.0         1.0    23.00   23.1000   18.71     19.20
# 2 days            0.0         1.0    25.00   25.9200   20.27     21.96
# 1 days            0.0         1.0    25.79   30.4192   23.30     23.83
# 0 days            0.0         1.0    19.00   25.0000   17.54     23.89
#
#             AdjVolume
# Date
# 2828 days  13696168.0
# 2827 days   8324639.0
# 2824 days   6600538.0
# 2823 days   4914307.0
# 2822 days   5927881.0
# ...               ...
# 7 days      6866900.0
# 3 days      5139800.0
# 2 days      8218800.0
# 1 days     17187100.0
# 0 days     18766300.0
#
# [1949 rows x 13 columns]

# %%
# 8일째 되는 날의 데이터를 출력하기
tesla.loc['8 days']
# Out:
# Date          2010-07-07 00:00:00
# Open                         16.4
# High                        16.63
# Low                         14.98
# Close                        15.8
# Volume                  6921700.0
# ExDividend                    0.0
# SplitRatio                    1.0
# AdjOpen                      16.4
# AdjHigh                     16.63
# AdjLow                      14.98
# AdjClose                     15.8
# AdjVolume               6921700.0
# Name: 8 days 00:00:00, dtype: object

# %%
ebola = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/country_timeseries.csv',parse_dates=[0])
ebola

range_num = range(0,10)          # 숫자

# 날짜를 범위로 가져오기
head_range = pd.date_range(start = '2014-12-31', end = '2015-01-04')
head_range
# Out:
# DatetimeIndex(['2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04'],
#               dtype='datetime64[ns]', freq='D')

# %%
ebola_5 = ebola.head(5)
ebola_5['Date']
# Out:
# 0   2015-01-05
# 1   2015-01-04
# 2   2015-01-03
# 3   2015-01-02
# 4   2014-12-31
# Name: Date, dtype: datetime64[ns]

# %%
ebola_5.index = ebola_5['Date']
ebola_5
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 2015-01-05            NaN            NaN                 NaN          NaN
# 2015-01-04            NaN            NaN                 NaN          NaN
# 2015-01-03            NaN            NaN                 NaN          NaN
# 2015-01-02            NaN            NaN                 NaN          NaN
# 2014-12-31            NaN            NaN                 NaN          NaN
#
#             Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# Date
# 2015-01-05         NaN         1786.0             NaN              2977.0
# 2015-01-04         NaN         1781.0             NaN              2943.0
# 2015-01-03         NaN         1767.0          3496.0              2915.0
# 2015-01-02         NaN            NaN          3496.0                 NaN
# 2014-12-31         NaN         1739.0          3471.0              2827.0
#
#             Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# Date
# 2015-01-05             NaN             NaN                  NaN           NaN
# 2015-01-04             NaN             NaN                  NaN           NaN
# 2015-01-03             NaN             NaN                  NaN           NaN
# 2015-01-02             NaN             NaN                  NaN           NaN
# 2014-12-31             NaN             NaN                  NaN           NaN
#
#             Deaths_Mali
# Date
# 2015-01-05          NaN
# 2015-01-04          NaN
# 2015-01-03          NaN
# 2015-01-02          NaN
# 2014-12-31          NaN

# %%
# 시간 index로 변경
ebola_5.reindex(head_range)
ebola_5
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 2015-01-05            NaN            NaN                 NaN          NaN
# 2015-01-04            NaN            NaN                 NaN          NaN
# 2015-01-03            NaN            NaN                 NaN          NaN
# 2015-01-02            NaN            NaN                 NaN          NaN
# 2014-12-31            NaN            NaN                 NaN          NaN
#
#             Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# Date
# 2015-01-05         NaN         1786.0             NaN              2977.0
# 2015-01-04         NaN         1781.0             NaN              2943.0
# 2015-01-03         NaN         1767.0          3496.0              2915.0
# 2015-01-02         NaN            NaN          3496.0                 NaN
# 2014-12-31         NaN         1739.0          3471.0              2827.0
#
#             Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# Date
# 2015-01-05             NaN             NaN                  NaN           NaN
# 2015-01-04             NaN             NaN                  NaN           NaN
# 2015-01-03             NaN             NaN                  NaN           NaN
# 2015-01-02             NaN             NaN                  NaN           NaN
# 2014-12-31             NaN             NaN                  NaN           NaN
#
#             Deaths_Mali
# Date
# 2015-01-05          NaN
# 2015-01-04          NaN
# 2015-01-03          NaN
# 2015-01-02          NaN
# 2014-12-31          NaN

# %%
ebola_5.index = head_range[::-1]
ebola_5
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 2015-01-04 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-03 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-02 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-01 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 2015-01-04            NaN            NaN                 NaN          NaN
# 2015-01-03            NaN            NaN                 NaN          NaN
# 2015-01-02            NaN            NaN                 NaN          NaN
# 2015-01-01            NaN            NaN                 NaN          NaN
# 2014-12-31            NaN            NaN                 NaN          NaN
#
#             Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# 2015-01-04         NaN         1786.0             NaN              2977.0
# 2015-01-03         NaN         1781.0             NaN              2943.0
# 2015-01-02         NaN         1767.0          3496.0              2915.0
# 2015-01-01         NaN            NaN          3496.0                 NaN
# 2014-12-31         NaN         1739.0          3471.0              2827.0
#
#             Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# 2015-01-04             NaN             NaN                  NaN           NaN
# 2015-01-03             NaN             NaN                  NaN           NaN
# 2015-01-02             NaN             NaN                  NaN           NaN
# 2015-01-01             NaN             NaN                  NaN           NaN
# 2014-12-31             NaN             NaN                  NaN           NaN
#
#             Deaths_Mali
# 2015-01-04          NaN
# 2015-01-03          NaN
# 2015-01-02          NaN
# 2015-01-01          NaN
# 2014-12-31          NaN

# %%
# 에볼라의 확산 속도 비교하기
ebola.index=  ebola['Date']
fig , ax = plt.subplots()
ax = ebola.iloc[:,1:].plot(ax = ax)
ax.legend(fontsize = 7,loc = 2, borderaxespad = 0)
plt.show()

# %%
ebola = pd.read_csv('https://raw.githubusercontent.com/SoongMoo/soldesk20231218/main/data/country_timeseries.csv',parse_dates=[0])
ebola.head().iloc[:,0:5]
ebola.index = ebola['Date']

# %%
ebola_shift = ebola.drop(['Date','Day'] , axis= 1)
ebola_shift
# Out:
#             Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# Date
# 2015-01-05        2776.0            NaN            10030.0            NaN
# 2015-01-04        2775.0            NaN             9780.0            NaN
# 2015-01-03        2769.0         8166.0             9722.0            NaN
# 2015-01-02           NaN         8157.0                NaN            NaN
# 2014-12-31        2730.0         8115.0             9633.0            NaN
# ...                  ...            ...                ...            ...
# 2014-03-27         103.0            8.0                6.0            NaN
# 2014-03-26          86.0            NaN                NaN            NaN
# 2014-03-25          86.0            NaN                NaN            NaN
# 2014-03-24          86.0            NaN                NaN            NaN
# 2014-03-22          49.0            NaN                NaN            NaN
#
#             Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# Date
# 2015-01-05            NaN                 NaN          NaN         NaN
# 2015-01-04            NaN                 NaN          NaN         NaN
# 2015-01-03            NaN                 NaN          NaN         NaN
# 2015-01-02            NaN                 NaN          NaN         NaN
# 2014-12-31            NaN                 NaN          NaN         NaN
# ...                   ...                 ...          ...         ...
# 2014-03-27            NaN                 NaN          NaN         NaN
# 2014-03-26            NaN                 NaN          NaN         NaN
# 2014-03-25            NaN                 NaN          NaN         NaN
# 2014-03-24            NaN                 NaN          NaN         NaN
# 2014-03-22            NaN                 NaN          NaN         NaN
#
#             Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# Date
# 2015-01-05         1786.0             NaN              2977.0             NaN
# 2015-01-04         1781.0             NaN              2943.0             NaN
# 2015-01-03         1767.0          3496.0              2915.0             NaN
# 2015-01-02            NaN          3496.0                 NaN             NaN
# 2014-12-31         1739.0          3471.0              2827.0             NaN
# ...                   ...             ...                 ...             ...
# 2014-03-27           66.0             6.0                 5.0             NaN
# 2014-03-26           62.0             NaN                 NaN             NaN
# 2014-03-25           60.0             NaN                 NaN             NaN
# 2014-03-24           59.0             NaN                 NaN             NaN
# 2014-03-22           29.0             NaN                 NaN             NaN
#
#             Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# Date
# 2015-01-05             NaN                  NaN           NaN          NaN
# 2015-01-04             NaN                  NaN           NaN          NaN
# 2015-01-03             NaN                  NaN           NaN          NaN
# 2015-01-02             NaN                  NaN           NaN          NaN
# 2014-12-31             NaN                  NaN           NaN          NaN
# ...                    ...                  ...           ...          ...
# 2014-03-27             NaN                  NaN           NaN          NaN
# 2014-03-26             NaN                  NaN           NaN          NaN
# 2014-03-25             NaN                  NaN           NaN          NaN
# 2014-03-24             NaN                  NaN           NaN          NaN
# 2014-03-22             NaN                  NaN           NaN          NaN
#
# [122 rows x 16 columns]

# %%
ebola_shifts = ebola_shift.drop(['2015-01-05','2015-01-03'], axis = 0)
ebola_shifts
# Out:
#             Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# Date
# 2015-01-04        2775.0            NaN             9780.0            NaN
# 2015-01-02           NaN         8157.0                NaN            NaN
# 2014-12-31        2730.0         8115.0             9633.0            NaN
# 2014-12-28        2706.0         8018.0             9446.0            NaN
# 2014-12-27        2695.0            NaN             9409.0            NaN
# ...                  ...            ...                ...            ...
# 2014-03-27         103.0            8.0                6.0            NaN
# 2014-03-26          86.0            NaN                NaN            NaN
# 2014-03-25          86.0            NaN                NaN            NaN
# 2014-03-24          86.0            NaN                NaN            NaN
# 2014-03-22          49.0            NaN                NaN            NaN
#
#             Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# Date
# 2015-01-04            NaN                 NaN          NaN         NaN
# 2015-01-02            NaN                 NaN          NaN         NaN
# 2014-12-31            NaN                 NaN          NaN         NaN
# 2014-12-28            NaN                 NaN          NaN         NaN
# 2014-12-27            NaN                 NaN          NaN         NaN
# ...                   ...                 ...          ...         ...
# 2014-03-27            NaN                 NaN          NaN         NaN
# 2014-03-26            NaN                 NaN          NaN         NaN
# 2014-03-25            NaN                 NaN          NaN         NaN
# 2014-03-24            NaN                 NaN          NaN         NaN
# 2014-03-22            NaN                 NaN          NaN         NaN
#
#             Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# Date
# 2015-01-04         1781.0             NaN              2943.0             NaN
# 2015-01-02            NaN          3496.0                 NaN             NaN
# 2014-12-31         1739.0          3471.0              2827.0             NaN
# 2014-12-28         1708.0          3423.0              2758.0             NaN
# 2014-12-27         1697.0             NaN              2732.0             NaN
# ...                   ...             ...                 ...             ...
# 2014-03-27           66.0             6.0                 5.0             NaN
# 2014-03-26           62.0             NaN                 NaN             NaN
# 2014-03-25           60.0             NaN                 NaN             NaN
# 2014-03-24           59.0             NaN                 NaN             NaN
# 2014-03-22           29.0             NaN                 NaN             NaN
#
#             Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# Date
# 2015-01-04             NaN                  NaN           NaN          NaN
# 2015-01-02             NaN                  NaN           NaN          NaN
# 2014-12-31             NaN                  NaN           NaN          NaN
# 2014-12-28             NaN                  NaN           NaN          NaN
# 2014-12-27             NaN                  NaN           NaN          NaN
# ...                    ...                  ...           ...          ...
# 2014-03-27             NaN                  NaN           NaN          NaN
# 2014-03-26             NaN                  NaN           NaN          NaN
# 2014-03-25             NaN                  NaN           NaN          NaN
# 2014-03-24             NaN                  NaN           NaN          NaN
# 2014-03-22             NaN                  NaN           NaN          NaN
#
# [120 rows x 16 columns]
